# %%
import numpy as np
from numpy.random import randn

import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams

import seaborn as sb

# %%
# %matplotlib inline 
rcParams['figure.figsize'] = 8,4
plt.style.use('seaborn-whitegrid')

# %%
address = '/Users/fyenne/Desktop/booooks/python/Python_course/Exercise Files/Data/iris.csv'
df = pd.read_csv(address, header = 'infer') #header = infer
df.head()
# cars.columns.values[0]='car_names' # rename first_position, col_name 
# cars.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # outlier plot

# %%
X = df.iloc[:, 1:5].values
Y = df.iloc[:, 4].values

df1 = df.drop(df.columns[[0]], axis = 1)
df1.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1.boxplot(return_type='dict')
plt.plot()
# 第二箱有outliers
# Out:
# []

# %%
Sepal_Width = X[:,1]
iris_outliers = (Sepal_Width > 4)
df1[iris_outliers]
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 15           5.7          4.4           1.5          0.4  setosa
# 32           5.2          4.1           1.5          0.1  setosa
# 33           5.5          4.2           1.4          0.2  setosa

# %%
Sepal_Width = X[:,1]
iris_outliers = (Sepal_Width < 2.05)
df1[iris_outliers]
# Out:
#     Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 60           5.0          2.0           3.5          1.0  versicolor

# %%
pd.options.display.float_format = '{:.1f}'.format 
# string value contains a dictionary in {}
X_df = pd.DataFrame(X)
print(X_df.describe())
# Out:
#           0     1     2     3
# count 150.0 150.0 150.0 150.0
# mean    5.8   3.1   3.8   1.2
# std     0.8   0.4   1.8   0.8
# min     4.3   2.0   1.0   0.1
# 25%     5.1   2.8   1.6   0.3
# 50%     5.8   3.0   4.3   1.3
# 75%     6.4   3.3   5.1   1.8
# max     7.9   4.4   6.9   2.5

# %%
# thisdict =	{
#   "brand": "Ford",
#   "model": "Mustang",
#   "year": 1964
# }
# print(thisdict)
# print("brand")
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}
# brand

# %% [markdown]
# # detect outlier in multivariate.

# %%
 # iris data 05_09
df1.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## boxplot

# %%
data = df1.iloc[:,0:4].values
target = df1.iloc[:,4].values
# data
df1[:5]

sb.boxplot(x = 'Species', 
           y = 'Sepal.Length',
           data = df1,
          palette = 'hls')

# %% [markdown]
# ## Scatter plot

# %%
sb.pairplot(df1, hue = 'Species', palette = 'hls')
