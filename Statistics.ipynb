# %%
import numpy as np
from numpy.random import randn

import pandas as pd
from pandas import Series, DataFrame

import scipy
from scipy import stats

# %% [markdown]
# # summrising statistics number!

# %%
address = '/Users/fyenne/Desktop/booooks/python/Python_course/Exercise Files/Data/mtcars.csv'
cars = pd.read_csv(address) #header = infer

cars.columns.values[0]='car_names' # rename first_position, col_name 
cars.head()
# Out:
#            car_names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
cars.sum() # col sum 
cars.sum(axis = 1) # row sum
# Out:
# 0     328.980
# 1     329.795
# 2     259.580
# 3     426.135
# 4     590.310
# 5     385.540
# 6     656.920
# 7     270.980
# 8     299.570
# 9     350.460
# 10    349.660
# 11    510.740
# 12    511.500
# 13    509.850
# 14    728.560
# 15    726.644
# 16    725.695
# 17    213.850
# 18    195.165
# 19    206.955
# 20    273.775
# 21    519.650
# 22    506.085
# 23    646.280
# 24    631.175
# 25    208.215
# 26    272.570
# 27    273.683
# 28    670.690
# 29    379.590
# 30    694.710
# 31    288.890
# dtype: float64

# %%
cars.median()
cars.max()
# Out:
# car_names    Volvo 142E
# mpg                33.9
# cyl                   8
# disp                472
# hp                  335
# drat               4.93
# wt                5.424
# qsec               22.9
# vs                    1
# am                    1
# gear                  5
# carb                  8
# dtype: object

# %%
mpg = cars.mpg
mpg.idxmax(axis = 0)
# Out:
# 19

# %%
cars.std()
cars.var()
# Out:
# mpg        36.324103
# cyl         3.189516
# disp    15360.799829
# hp       4700.866935
# drat        0.285881
# wt          0.957379
# qsec        3.193166
# vs          0.254032
# am          0.248992
# gear        0.544355
# carb        2.608871
# dtype: float64

# %%
gear = cars.gear
gear.value_counts() # gear has 3 different values == 3,4,5
# carname count
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
cars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# # categorical variable.

# %%
# address = 
# mtcars data 
cars.head(15)
# Out:
#              car_names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5              Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10           Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11          Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# ...

# %%
# ccgroup = cars.groupby('car_names') 
# # this would display carnames
# ccgroup.carb.value_counts()
# test = ccgroup.carb.value_counts()
# # testst
# #testst['group'] = pd.Series(test.carb, dtype = "category")

# %%
carb = cars.carb # 汽化器， 化油器
carb.value_counts()
# Out:
# 4    10
# 2    10
# 1     7
# 3     3
# 8     1
# 6     1
# Name: carb, dtype: int64

# %%
cars_cat = cars[['cyl', 'vs', 'am', 'gear', 'carb']] #subsetting
# get several cols you need
cars_cat.head()
# Out:
#    cyl  vs  am  gear  carb
# 0    6   0   1     4     4
# 1    6   0   1     4     4
# 2    4   1   1     4     1
# 3    6   1   0     3     1
# 4    8   0   0     3     2

# %%
gears_group = cars_cat.groupby('gear')
gears_group.describe()
# Out:
#        cyl                                                 vs            ...  \
#      count      mean       std  min  25%  50%  75%  max count      mean  ...
# gear                                                                     ...
# 3     15.0  7.466667  1.187234  4.0  8.0  8.0  8.0  8.0  15.0  0.200000  ...
# 4     12.0  4.666667  0.984732  4.0  4.0  4.0  6.0  6.0  12.0  0.833333  ...
# 5      5.0  6.000000  2.000000  4.0  4.0  6.0  8.0  8.0   5.0  0.200000  ...
#
#        am       carb
#       75%  max count      mean       std  min  25%  50%  75%  max
# gear
# 3     0.0  0.0  15.0  2.666667  1.175139  1.0  2.0  3.0  4.0  4.0
# 4     1.0  1.0  12.0  2.333333  1.302678  1.0  1.0  2.0  4.0  4.0
# 5     1.0  1.0   5.0  4.400000  2.607681  2.0  2.0  4.0  6.0  8.0
#
# [3 rows x 32 columns]

# %%
cars['group'] = pd.Series(cars.gear, dtype = "category") 
# creat new column
cars.head(5)
# Out:
#            car_names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb group
# 0     4     4
# 1     4     4
# 2     1     4
# 3     1     3
# 4     2     3

# %%
cars['group'].dtypes # categorical variable. Factors in r
# Out:
# CategoricalDtype(categories=[3, 4, 5], ordered=False)

# %%
cars['group'].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: group, dtype: int64

# %% [markdown]
# ## describing categorical data with crosstabs.
#
# ### crosstab == summarise in table

# %%
pd.crosstab(cars['am'], cars['gear']) # 
# pd.crosstab(index=, columns = )
# Out:
# gear   3  4  5
# am
# 0     15  4  0
# 1      0  8  5
